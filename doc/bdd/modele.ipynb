# %%
# %reload_ext mocodo_magic

# %%
# %%mocodo --mld --colors brewer+1 --shapes copperplate --relations diagram markdown_data_dict
#
# Students: IdStudent, StdFirstname, StdLastname, OrderKey
# sitsAt, 0N Students, 11 Desks
# Desks: IdDesk, DeskRow, DeskCol
# belongs to, 1N Courses, 11 Desks
# Courses: IdCourse, CourseName
#
#     :
# IsIn, 1N Students, 1N Groups
# Groups: IdGroup, GroupName
# :
# IsAbout, 11 Courses, 1N Topics
#
# HasAttributes,  11 StdAttrs, 1N Students, NN Attributes, 1N Topics
# StdAttrs: IdStdAttr, StdAttrValue
#     :
# Topics: IdTopic, TopicName
#
# Attributes: IdAttr, AttrName
# IsOfType, 1N AttrTypes, 11 Attributes
# AttrTypes: IdAttrType, AttrTypeName
# :
# Out:
# <html>
# <head>
# <meta charset='utf-8'>
# <style>
#   #mld .relation { font-variant: small-caps; font-weight: bold }
#   #mld .primary { text-decoration: underline }
#   #mld .foreign { font-style: oblique }
#   #mld .normal { }
# </style>
# </head>
# <body>
# <div id='mld'>
# <div>
#   <span class='relation'>Students</span> (
#     <span class='primary'>IdStudent</span>,
#     <span class='normal'>StdFirstname</span>,
#     <span class='normal'>StdLastname</span>,
#     <span class='normal'>OrderKey</span>
#   )
# </div>
# <div>
#   <span class='relation'>Desks</span> (
#     <span class='primary'>IdDesk</span>,
#     <span class='normal'>DeskRow</span>,
#     <span class='normal'>DeskCol</span>,
#     <span class='foreign'>IdStudent</span>,
#     <span class='foreign'>IdCourse</span>
#   )
# </div>
# <div>
#   <span class='relation'>Courses</span> (
#     <span class='primary'>IdCourse</span>,
#     <span class='normal'>CourseName</span>,
#     <span class='foreign'>IdTopic</span>
#   )
# </div>
# <div>
#   <span class='relation'>IsIn</span> (
#     <span class='foreign primary'>IdStudent</span>,
#     <span class='foreign primary'>IdGroup</span>
#   )
# </div>
# <div>
#   <span class='relation'>Groups</span> (
#     <span class='primary'>IdGroup</span>,
#     <span class='normal'>GroupName</span>
#   )
# </div>
# <div>
#   <span class='relation'>StdAttrs</span> (
#     <span class='primary'>IdStdAttr</span>,
#     <span class='normal'>StdAttrValue</span>,
#     <span class='foreign'>IdStudent</span>,
#     <span class='foreign'>IdAttr</span>,
#     <span class='foreign'>IdTopic</span>
#   )
# </div>
# <div>
#   <span class='relation'>Topics</span> (
#     <span class='primary'>IdTopic</span>,
#     <span class='normal'>TopicName</span>
#   )
# </div>
# <div>
#   <span class='relation'>Attributes</span> (
#     <span class='primary'>IdAttr</span>,
#     <span class='normal'>AttrName</span>,
#     <span class='foreign'>IdAttrType</span>
#   )
# </div>
# <div>
#   <span class='relation'>AttrTypes</span> (
#     <span class='primary'>IdAttrType</span>,
#     <span class='normal'>AttrTypeName</span>
#   )
# </div>
# </div>
# </body>
# </html>

# %%
# %mocodo --input mocodo_notebook/sandbox.mld --colors brewer+1
